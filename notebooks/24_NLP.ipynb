# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import regex as re
import nltk
from nltk import download
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
import tensorflow as tf
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay

# %%
download('wordnet')
download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = stopwords.words('english')

# %%
df_raw = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/machine-learning-content/master/assets/spam.csv")
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df_raw.sample(10, random_state=2025)
# Out:
#      Category                                            Message
# 2349      ham              That seems unnecessarily affectionate
# 5397      ham                      That's necessarily respectful
# 4028      ham      Yes, princess. Are you going to make me moan?
# 3165      ham  TODAY is Sorry day.! If ever i was angry with ...
# 2738      ham  Hi Chachi tried calling u now unable to reach ...
# 2504      ham  Fwiw the reason I'm only around when it's time...
# 378       ham  Well there's not a lot of things happening in ...
# 3799      ham  Feb  &lt;#&gt;  is "I LOVE U" day. Send dis to...
# 5138      ham  Yup... I havent been there before... You want ...
# 4086     spam  Orange brings you ringtones from all time Char...

# %%
#Step 2: Preprocessing
df_baking = df_raw.copy()
df_baking.columns = df_baking.columns.str.lower()
df_baking['message'] = df_baking['message'].str.lower()
df_baking['message'] = df_baking['message'].str.strip()
df_baking['message'] = df_baking['message'].apply(lambda x: "haven´t" if x == 'havent' else x)
df_baking['message'] = df_baking['message'].apply(lambda x: "this" if x == 'dis' else x)
df_baking['message'] = df_baking['message'].str.replace('&lt;#&gt;', '')
df_baking['category'] = df_baking['category'].astype('category')
df_baking = df_baking.drop_duplicates()

def preprocess_text(text:str)->list:
  text = re.sub(' dat ', ' that ', text)
  text = re.sub(' da ', ' the ', text)
  text = re.sub(' ur ', ' your ', text)
  text = re.sub(' ur ', ' your ', text)
  text = re.sub(' c ', ' see ', text)
  text = re.sub(' b ', ' be ', text)
  return text
df_baking['message'] = df_baking['message'].apply(preprocess_text)
df = df_baking.copy()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5156 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  5156 non-null   category
#  1   message   5156 non-null   object
# dtypes: category(1), object(1)
# memory usage: 85.7+ KB

# %%
df.sample(10, random_state=2025)
# Out:
#      category                                            message
# 2684      ham  i'm okay. chasing the dream. what's good. what...
# 2654      ham  sorry da:)i was thought of calling you lot of ...
# 4385      ham  thanks honey but still haven't heard anything ...
# 3124      ham  he telling not to tell any one. if so treat fo...
# 75        ham        i am waiting machan. call me once you free.
# 2141      ham            after the drug she will be able to eat.
# 3346      ham      reverse is cheating. that is not mathematics.
# 798       ham  petey boy whereare you me and all your friends...
# 2013      ham  beautiful truth against gravity.. read careful...
# 5320      ham              but we havent got the topic yet rite?

# %%
#Step 3: EDA
df_train, df_test = train_test_split(df, test_size=0.2, stratify=df['category'], random_state=2025)
df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
df_train.shape, df_test.shape
# Out:
# ((4124, 2), (1032, 2))

# %%
df_train.describe().T
# Out:
#          count unique                                     top  freq
# category  4124      2                                     ham  3611
# message   4124   4124  get ready for    inches of pleasure...     1

# %%
sns.countplot(df_train, y='category')
plt.show()

# %%
df_train['message'].str.split(expand=True).stack().value_counts()[:20]
# Out:
# i       1720
# to      1611
# you     1446
# the     1043
# a       1042
# your     730
# and      722
# u        706
# in       641
# is       628
# my       564
# for      536
# me       460
# of       454
# have     433
# on       396
# that     388
# are      369
# call     363
# 2        345
# Name: count, dtype: int64

# %%
wc = WordCloud(
    max_words = 100,
    background_color = 'White',
    collocations = False
).generate(' '.join(df_train['message']))
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.show()

# %%
wc = WordCloud(
    max_words = 100,
    background_color = 'White',
    collocations = False
).generate(' '.join(df_train[df_train['category'] == 'ham']['message']))
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.show()

# %%
wc = WordCloud(
    max_words = 100,
    background_color = 'White',
    collocations = False
).generate(' '.join(df_train[df_train['category'] == 'spam']['message']))
plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.show()

# %%
#Step 4: ML

token_train_X = df_train['message']
y_train = df_train['category']
token_test_X = df_test['message']
y_test = df_test['category']

label_encoder = LabelEncoder()
y_train_enc = label_encoder.fit_transform(y_train)
y_test_enc = label_encoder.transform(y_test)

# %%
vectorizer = TfidfVectorizer(max_features=5000, stop_words=stop_words)
X_train = vectorizer.fit_transform(token_train_X)
X_test = vectorizer.transform(token_test_X)

# %%
model = SVC(kernel='linear', random_state=2025, class_weight='balanced')
model.fit(X_train, y_train_enc)
# Out:
# SVC(class_weight='balanced', kernel='linear', random_state=2025)

# %%
y_hat = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test_enc, y_hat):.2f}')
# Out:
# Accuracy: 0.98

# %%
print(classification_report(y_test_enc, y_hat, target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.99      0.99      0.99       904
#         spam       0.94      0.93      0.94       128
#
#     accuracy                           0.98      1032
#    macro avg       0.97      0.96      0.96      1032
# weighted avg       0.98      0.98      0.98      1032

# %%
ConfusionMatrixDisplay.from_predictions(y_test_enc, y_hat, display_labels=label_encoder.classes_)
plt.show()

# %%
#Step 4.1 Deep Learning

vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1,2))
X_train = vectorizer.fit_transform(token_train_X)
X_test = vectorizer.transform(token_test_X)

X_train_array = X_train.toarray()
X_test_array = X_test.toarray()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(512, activation='relu', input_shape=(X_train_array.shape[1],)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
     tf.keras.layers.Dense(1, activation='sigmoid'),
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 512)            │     2,560,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,724,865 (10.39 MB)
#  Trainable params: 2,724,865 (10.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.Recall(name='recall')]
              )

# %%
history = model.fit(
    X_train_array, y_train_enc,
    epochs=100, batch_size=128,
    validation_split=0.15
)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.8741 - loss: 0.4808 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8675 - val_loss: 0.1807 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8766 - loss: 0.1370 - precision: 0.2069 - recall: 0.0179 - val_accuracy: 0.9677 - val_loss: 0.1484 - val_precision: 1.0000 - val_recall: 0.7561
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.9947 - loss: 0.0846 - precision: 1.0000 - recall: 0.9568 - val_accuracy: 0.9838 - val_loss: 0.1301 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9990 - loss: 0.0512 - precision: 0.9993 - recall: 0.9922 - val_accuracy: 0.9838 - val_loss: 0.0856 - val_precision: 0.9615 - val_recall: 0.9146
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9999 - loss: 0.0056 - precision: 1.0000 - recall: 0.9989 - val_accuracy: 0.9822 - val_loss: 0.0929 - val_precision: 0.9494 - val_recall: 0.9146
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9993 - loss: 0.0026 - precision: 1.0000 - recall: 0.9938 - val_accuracy: 0.9822 - val_loss: 0.1143 - val_precision: 0.9610 - val_recall: 0.9024
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9996 - loss: 0.0020 - precision: 1.0000 - recall: 0.9966 - val_accuracy: 0.9822 - val_loss: 0.1024 - val_precision: 0.9494 - val_recall: 0.9146
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.9998 - loss: 0.0012 - precision: 1.0000 - recall: 0.9983 - val_accuracy: 0.9806 - val_loss: 0.1022 - val_precision: 0.9375 - val_recall: 0.9146
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.
- val_precision: 0.9865 - val_recall: 0.8902
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9994 - loss: 0.0016 - precision: 1.0000 - recall: 0.9947 - val_accuracy: 0.9838 - val_loss: 0.1254 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.9998 - loss: 8.3531e-04 - precision: 1.0000 - recall: 0.9984 - val_accuracy: 0.9838 - val_loss: 0.1205 - val_precision: 0.9737 - val_recall: 0.9024
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9994 - loss: 0.0015 - precision: 1.0000 - recall: 0.9952 - val_accuracy: 0.9838 - val_loss: 0.1151 - val_precision: 0.9737 - val_recall: 0.9024
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9997 - loss: 0.0012 - precision: 1.0000 - recall: 0.9979 - val_accuracy: 0.9838 - val_loss: 0.1309 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9995 - loss: 0.0013 - precision: 1.0000 - recall: 0.9957 - val_accuracy: 0.9838 - val_loss: 0.1147 - val_precision: 0.9737 - val_recall: 0.9024
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9995 - loss: 0.0014 - precision: 1.0000 - recall: 0.9962 - val_accuracy: 0.9838 - val_loss: 0.1271 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9998 - loss: 8.4817e-04 - precision: 1.0000 - recall: 0.9984 - val_accuracy: 0.9838 - val_loss: 0.1194 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9997 - loss: 0.0012 - precision: 1.0000 - recall: 0.9974 - val_accuracy: 0.9838 - val_loss: 0.1101 - val_precision: 0.9737 - val_recall: 0.9024
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9992 - loss: 0.0020 - precision: 1.0000 - recall: 0.9939 - val_accuracy: 0.9838 - val_loss: 0.1253 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9994 - loss: 0.0016 - precision: 1.0000 - recall: 0.9948 - val_accuracy: 0.9838 - val_loss: 0.1196 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9997 - loss: 0.0014 - precision: 1.0000 - recall: 0.9974 - val_accuracy: 0.9855 - val_loss: 0.1170 - val_precision: 0.9867 - val_recall: 0.9024
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9992 - loss: 0.0017 - precision: 1.0000 - recall: 0.9938 - val_accuracy: 0.9838 - val_loss: 0.1188 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9999 - loss: 6.7858e-04 - precision: 1.0000 - recall: 0.9990 - val_accuracy: 0.9822 - val_loss: 0.1383 - val_precision: 0.9863 - val_recall: 0.8780
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.9995 - loss: 0.0013 - precision: 1.0000 - recall: 0.9956 - val_accuracy: 0.9855 - val_loss: 0.1158 - val_precision: 0.9867 - val_recall: 0.9024
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.9995 - loss: 0.0014 - precision: 1.0000 - recall: 0.9957 - val_accuracy: 0.9838 - val_loss: 0.1287 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9997 - loss: 0.0012 - precision: 1.0000 - recall: 0.9973 - val_accuracy: 0.9855 - val_loss: 0.1187 - val_precision: 0.9867 - val_recall: 0.9024
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9999 - loss: 7.1762e-04 - precision: 1.0000 - recall: 0.9990 - val_accuracy: 0.9838 - val_loss: 0.1269 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9992 - loss: 0.0021 - precision: 1.0000 - recall: 0.9932 - val_accuracy: 0.9838 - val_loss: 0.1204 - val_precision: 0.9865 - val_recall: 0.8902
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9993 - loss: 0.0018 - precision: 1.0000 - recall: 0.9942 - val_accuracy: 0.9822 - val_loss: 0.1523 - val_precision: 0.9863 - val_recall: 0.8780

# %%
model.evaluate(X_test_array, y_test_enc)
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9769 - loss: 0.1626 - precision: 0.9724 - recall: 0.8499
# [0.1417018175125122, 0.9806201457977295, 0.9736841917037964, 0.8671875]

# %%
from transformers import pipeline

# %%
sentiment_pipeline = pipeline('sentiment-analysis', model='tabularisai/multilingual-sentiment-analysis')
# Out:
# config.json:   0%|          | 0.00/851 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Device set to use cpu

# %%
text = "las uvas son frutas"
result = sentiment_pipeline(text)
print(result)
# Out:
# [{'label': 'Neutral', 'score': 0.6421539783477783}]
